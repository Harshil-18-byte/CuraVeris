# %% [markdown]
# # 01. Data Exploration — MedBill Synthetic & Statutory Healthcare Invoices
# Analyzes the distribution of bill totals, Indian diagnosis frequencies, procedure costs, and error rates.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

bills = []
with open('../data/processed/synthetic_bills.jsonl', 'r') as f:
    for line in f:
        bills.append(json.loads(line))

df_bills = pd.DataFrame(bills)
print(f"Loaded {len(df_bills)} hospital bills.")
df_bills[['hospital_name', 'city', 'diagnosis', 'total_amount']].head(10)
