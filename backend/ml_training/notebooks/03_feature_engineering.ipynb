# %% [markdown]
# # 03. Feature Engineering for Hospital Overcharge Detection
# Generates the 8 multi-factor risk features:
# 1. `rate_vs_cghs_ratio`
# 2. `quantity_zscore`
# 3. `category_encoded`
# 4. `amount_percentile`
# 5. `consumable_ratio`
# 6. `has_icd_code`
# 7. `similarity_score`
# 8. `gst_rate_correct`

# %%
import sys; sys.path.insert(0, '../scripts')
from train_classifier import build_dataset

df_features = build_dataset('../data/processed/synthetic_bills.jsonl')
print("Feature matrix preview:")
df_features.describe()
