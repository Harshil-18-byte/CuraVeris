# %% [markdown]
# # 04. Multi-Label XGBoost Classifier Training
# Trains XGBoost with SMOTE oversampling to tackle severe class imbalance across statutory error classes.

# %%
import os
os.environ['OMP_NUM_THREADS'] = '1'
import joblib

model = joblib.load('../models/risk_classifier.pkl')
print("Loaded trained multi-label XGBoost classifier:")
print(model)
