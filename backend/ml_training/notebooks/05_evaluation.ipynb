# %% [markdown]
# # 05. Model Evaluation & ROC Analysis
# Comprehensive validation across multi-label confusion matrices, Macro AUC-ROC, and Hamming Loss.

# %%
import sys; sys.path.insert(0, '../scripts')
from evaluate_model import main

main()
